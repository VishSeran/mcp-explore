# %% [markdown]
# ## **Build MCP Applications**

# %% [markdown]
# * Build MCP applications using Local implement `(STDIO)`

# %%
from fastmcp import Client
from fastmcp.client.transports import StdioTransport

# %%
stdio_transport = StdioTransport(
    command="npx",
    args=["-y", "@upstash/context7-mcp"]
)

# %%
stdio_client = Client(stdio_transport)

# %%
async def tools_extract():
    async with stdio_client as client:
        tools = await client.list_tools()
        
        for tool in tools:
            print("tools: ", tool.name)

# %%
tools = tools_extract()
# Out:
# C:\Users\Vish\AppData\Local\Temp\ipykernel_29208\2193953537.py:1: RuntimeWarning: coroutine 'tools_extract' was never awaited
#   tools = tools_extract()
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback

# %%
tools
# Out:
# <coroutine object tools_extract at 0x000001FE45AB26B0>

# %%
import asyncio
from fastmcp import Client
from fastmcp.client.transports import StdioTransport

stdio_transport = StdioTransport(
    command="npx",
    args=["-y", "@upstash/context7-mcp"]
)

stdio_client = Client(stdio_transport) 

async def main():
    async with stdio_client as client:
        result = await client.list_tools()
        print(result)

# %%
main()
# Out:
# <coroutine object main at 0x000001FE45AB1A80>
