# %% [markdown]
# ## **Build MCP Applications**

# %% [markdown]
# * Build MCP applications using Local implement `(STDIO)`

# %%
from fastmcp import Client
from fastmcp.client.transports import StdioTransport

# %%
stdio_transport = StdioTransport(
    command="npx",
    args=["-y", "@upstash/context7-mcp"]
)

# %%
stdio_client = Client(stdio_transport)

# %%
async def tools_extract():
    async with stdio_client as client:
        tools = await client.list_tools()
        
        for tool in tools:
            print("tools: ", tool.name)

# %%
tools = tools_extract()
# Out:
# C:\Users\Vish\AppData\Local\Temp\ipykernel_29208\2193953537.py:1: RuntimeWarning: coroutine 'tools_extract' was never awaited
#   tools = tools_extract()
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback

# %%
tools
# Out:
# <coroutine object tools_extract at 0x000001FE45AB26B0>

# %%
from fastmcp import Client
from fastmcp.client.transports import StdioTransport

stdio_transport = StdioTransport(
    command="npx",
    args=["-y", "@upstash/context7-mcp"]
)

stdio_client = Client(stdio_transport)

async with stdio_client as client:
    result = await client.list_tools()

result
# Out:
# ---------------------------------------------------------------------------
# ExceptionGroup                            Traceback (most recent call last)
# File d:\Projects\mcp-explore\venv\Lib\site-packages\exceptiongroup\_catch.py:63, in _Catcher.handle_exception(self, exc)
#      62 try:
# ---> 63     raise matched
#      64 except BaseExceptionGroup:
#
# ExceptionGroup:  (1 sub-exception)
#
# During handling of the above exception, another exception occurred:
#
# UnsupportedOperation                      Traceback (most recent call last)
# File d:\Projects\mcp-explore\venv\Lib\site-packages\fastmcp\client\client.py:702, in Client._session_runner(self)
#     701 async with AsyncExitStack() as stack:
# --> 702     await stack.enter_async_context(self._context_manager())
#     703     # Session/context is now ready
#
# File C:\Program Files\Python311\Lib\contextlib.py:638, in AsyncExitStack.enter_async_context(self, cm)
#     635     raise TypeError(f"'{cls.__module__}.{cls.__qualname__}' object does "
#     636                     f"not support the asynchronous context manager protocol"
#     637                    ) from None
# --> 638 result = await _enter(cm)
#     639 self._push_async_cm_exit(cm, _exit)
#
# File C:\Program Files\Python311\Lib\contextlib.py:204, in _AsyncGeneratorContextManager.__aenter__(self)
#     203 try:
# --> 204     return await anext(self.gen)
#     205 except StopAsyncIteration:
#
# File d:\Projects\mcp-explore\venv\Lib\site-packages\exceptiongroup\_catch.py:65, in _Catcher.handle_exception(self, exc)
#      64     except BaseExceptionGroup:
# ---> 65         result = handler(matched)
#      66 except BaseExceptionGroup as new_exc:
#
# File d:\Projects\mcp-explore\venv\Lib\site-packages\fastmcp\utilities\exceptions.py:29, in _exception_handler(group)
#      23     raise McpError(
#      24         error=mcp.types.ErrorData(
#      25             code=httpx.codes.REQUEST_TIMEOUT,
#      26             message="Timed out while waiting for response.",
#      27         )
#      28     )
# ---> 29 raise leaf
#
# File d:\Projects\mcp-explore\venv\Lib\site-packages\fastmcp\client\client.py:469, in Client._context_manager(self)
#     468 with catch(get_catch_handlers()):
# --> 469     async with self.transport.connect_session(
#     470         **self._session_kwargs
#     471     ) as session:
#     472         self._session_state.session = session
#
# File C:\Program Files\Python311\Lib\contextlib.py:204, in _AsyncGeneratorContextManager.__aenter__(self)
#     203 try:
# --> 204     return await anext(self.gen)
#     205 except StopAsyncIteration:
#
# File d:\Projects\mcp-explore\venv\Lib\site-packages\fastmcp\client\transports\stdio.py:75, in StdioTransport.connect_session(self, **session_kwargs)
#      74 try:
# ---> 75     await self.connect(**session_kwargs)
#      76     yield cast(ClientSession, self._session)
#
# File d:\Projects\mcp-explore\venv\Lib\site-packages\fastmcp\client\transports\stdio.py:121, in StdioTransport.connect(self, **session_kwargs)
#     120     if exception is not None:
# --> 121         raise exception
#     123 self._session = await session_future
#
# File d:\Projects\mcp-explore\venv\Lib\site-packages\fastmcp\client\transports\stdio.py:207, in _stdio_transport_connect_task(command, args, env, cwd, log_file, session_kwargs, ready_event, stop_event, session_future)
#     205     log_file_handle = log_file
# --> 207 transport = await stack.enter_async_context(
#     208     stdio_client(server_params, errlog=log_file_handle)
#     209 )
#     210 read_stream, write_stream = transport
#
# File C:\Program Files\Python311\Lib\contextlib.py:638, in AsyncExitStack.enter_async_context(self, cm)
#     635     raise TypeError(f"'{cls.__module__}.{cls.__qualname__}' object does "
#     636                     f"not support the asynchronous context manager protocol"
#     637                    ) from None
# --> 638 result = await _enter(cm)
#     639 self._push_async_cm_exit(cm, _exit)
#
# File C:\Program Files\Python311\Lib\contextlib.py:204, in _AsyncGeneratorContextManager.__aenter__(self)
#     203 try:
# --> 204     return await anext(self.gen)
#     205 except StopAsyncIteration:
#
# File d:\Projects\mcp-explore\venv\Lib\site-packages\mcp\client\stdio\__init__.py:124, in stdio_client(server, errlog)
#     123     # Open process with stderr piped for capture
# --> 124     process = await _create_platform_compatible_process(
#     125         command=command,
#     126         args=server.args,
#     127         env=({**get_default_environment(), **server.env} if server.env is not None else get_default_environment()),
#     128         errlog=errlog,
#     129         cwd=server.cwd,
#     130     )
#     131 except OSError:
#     132     # Clean up streams if process creation fails
#
# File d:\Projects\mcp-explore\venv\Lib\site-packages\mcp\client\stdio\__init__.py:249, in _create_platform_compatible_process(command, args, env, errlog, cwd)
#     248 if sys.platform == "win32":  # pragma: no cover
# --> 249     process = await create_windows_process(command, args, env, errlog, cwd)
#     250 else:
#
# File d:\Projects\mcp-explore\venv\Lib\site-packages\mcp\os\win32\utilities.py:181, in create_windows_process(command, args, env, errlog, cwd)
#     179 except NotImplementedError:
#     180     # If Windows doesn't support async subprocess creation, use fallback
# --> 181     process = await _create_windows_fallback_process(command, args, env, errlog, cwd)
#     182 except Exception:
#     183     # Try again without creation flags
#
# File d:\Projects\mcp-explore\venv\Lib\site-packages\mcp\os\win32\utilities.py:221, in _create_windows_fallback_process(command, args, env, errlog, cwd)
#     219 except Exception:
#     220     # If creationflags failed, fallback without them
# --> 221     popen_obj = subprocess.Popen(
#     222         [command, *args],
#     223         stdin=subprocess.PIPE,
#     224         stdout=subprocess.PIPE,
#     225         stderr=errlog,
#     226         env=env,
#     227         cwd=cwd,
#     228         bufsize=0,
#     229     )
#     230 return FallbackProcess(popen_obj)
#
# File C:\Program Files\Python311\Lib\subprocess.py:992, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#     975 # Input and output objects. The general principle is like
#     976 # this:
#     977 #
#    (...)    987 # are -1 when not using PIPEs. The child objects are -1
#     988 # when not redirecting.
#     990 (p2cread, p2cwrite,
#     991  c2pread, c2pwrite,
# --> 992  errread, errwrite) = self._get_handles(stdin, stdout, stderr)
#     994 # From here on, raising exceptions may cause file descriptor leakage
#     995
#     996 # We wrap OS handles *before* launching the child, otherwise a
#     997 # quickly terminating child could make our fds unwrappable
#     998 # (see #8458).
#
# File C:\Program Files\Python311\Lib\subprocess.py:1406, in Popen._get_handles(self, stdin, stdout, stderr)
#    1404 else:
#    1405     # Assuming file-like object
# -> 1406     errwrite = msvcrt.get_osfhandle(stderr.fileno())
#    1407 errwrite = self._make_inheritable(errwrite)
#
# File d:\Projects\mcp-explore\venv\Lib\site-packages\ipykernel\iostream.py:458, in OutStream.fileno(self)
#     457 msg = "fileno"
# --> 458 raise io.UnsupportedOperation(msg)
#
# UnsupportedOperation: fileno
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[40], line 11
#       7 )
#       8
#       9 stdio_client = Client(stdio_transport)
#      10
# ---> 11 async with stdio_client as client:
#      12     result = await client.list_tools()
#      13
#      14 result
#
# File d:\Projects\mcp-explore\venv\Lib\site-packages\fastmcp\client\client.py:535, in Client.__aenter__(self)
#     534 async def __aenter__(self):
# --> 535     return await self._connect()
#
# File d:\Projects\mcp-explore\venv\Lib\site-packages\fastmcp\client\client.py:622, in Client._connect(self)
#     620             if isinstance(exception, httpx.HTTPStatusError | McpError):
#     621                 raise exception
# --> 622             raise RuntimeError(
#     623                 f"Client failed to connect: {exception}"
#     624             ) from exception
#     626     self._session_state.nesting_counter += 1
#     628 return self
#
# RuntimeError: Client failed to connect: fileno

# %%
result
# Out:
# <coroutine object ClientToolsMixin.list_tools at 0x000001FE45A2E560>
